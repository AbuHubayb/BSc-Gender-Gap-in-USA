# %% [markdown]
# ## This project intends to visualize the gap between the male and female BSc graduates of colleges across the years 1970 to 2011.
#
# **The data was taken from The Department of Education Statistics data set released annually on http://nces.ed.gov/programs/digest/2013menu_tables.asp ***
#
# The outcome should present answers to the following questions;
#
#         1. What was the level of involvement/awareness of women as regards the attainment of a Bachelor's degree?
#         2. Has there been any changes over the years?
#         3. What is the trend across various disciples?
#         4. What's the future like for individual courses? Are there chances that women would get more involved than men?

# %% [markdown]
# ### Read in the file

# %%
# import the necessary modules and libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
women_degrees.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %% [markdown]
# The colors for the line plots should be called now

# %%
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

# %% [markdown]
# Presenting the courses in categories would be an easier way to visualize them

# %%
stem_cats =     ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 
                 'Social Sciences and History']
other_cats =    ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %% [markdown]
# ### Making-out the plot

# %%
fig = plt.figure(figsize=(18, 18))


# Plotting for the first category, stem_cats

for i in range(0,6): 
    ax = fig.add_subplot(6,3,(3 * i) + 1, xticklabels=[], yticklabels=[], xticks=[], yticks=[])
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, linewidth=3)
#     plot for men's degrees would be 100-women's
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, linewidth=3)
    
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if i == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif i == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        
        

# Ploting for the second category, library arts category

for i in range(0,5): 
    ax = fig.add_subplot(6,3,(3 * i) + 2, xticklabels=[], yticklabels=[], xticks=[], yticks=[])
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, linewidth=3)
    
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if i == 0:
        ax.text(2005, 8, 'Men')
        ax.text(2002, 87, 'Women')
    elif i == 4:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        
        
                
# Ploting for the last category, other_cat

for i in range(0,6): 
    ax = fig.add_subplot(6,3,(3 * i) + 3, xticklabels=[], yticklabels=[], xticks=[], yticks=[])
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, linewidth=3)
       
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[i])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if i == 0:
        ax.text(2005, 8, 'Men')
        ax.text(2002, 87, 'Women')
    elif i == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')

plt.show()
# fig.savefig('Women-Men Degrees.png', format='png')

# %% [markdown]
# ### Conclusion
#
# Architecture, physical sciences, business, agriculture, computer science and engineering witnessed low involvement of women at the earliest times. Engineering had the highest gap in this regard.
#
# Women seems to prefer health professions, foreign language, education, public admin and english than men. This didnt change over time.
#
# The women overtook the men in psychology, communication & journalism and biology, greatly closed the gender gap in architecture, agriculture and maths & stats but strongly competing in business, social sciences and agriculture.
#
# | Course  | Remark|
# | -------------------- | ------------------------ |
# |Engineering | Needs improvement
# | Computer Science | need improvement
# | Psychology | doing well
# | Biology | doing well
# | Physical Sciences | competing
# | Math and Statistics | competing
# | Foreign Languages | doing well
# | English | doing well
# | Communications and Journalism | doing well
# | Art and Performance | doing well
# | Social Sciences and History | strongly competing
# | Health Professions | doing well
# | Public Administration | doing well
# | Education | doing well
# | Agriculture | strongly competing
# | Business | strongly competing
# | Architecture | strongly competing
